# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load the Dataset

# %%
data = pd.read_excel(r'C:\Users\HELLO\Favorites\Downloads\Bepec\dataset\INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls')

# %% [markdown]
# ### Read the data

# %%
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %%
data.shape
# Out:
# (1200, 28)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %%
data.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %% [markdown]
# ### Checking For Null Values in the dataset

# %%
data.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %% [markdown]
# ##### There is no any null values present in the dataset

# %%
data['Age'].unique()
# Out:
# array([32, 47, 40, 41, 60, 27, 50, 28, 36, 38, 44, 30, 29, 42, 34, 39, 56,
#        53, 35, 52, 33, 25, 45, 23, 26, 54, 37, 24, 49, 55, 43, 51, 22, 31,
#        58, 20, 21, 48, 19, 18, 59, 46, 57], dtype=int64)

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data['EducationBackground'].unique()
# Out:
# array(['Marketing', 'Life Sciences', 'Human Resources', 'Medical',
#        'Other', 'Technical Degree'], dtype=object)

# %%
data['MaritalStatus'].unique()
# Out:
# array(['Single', 'Married', 'Divorced'], dtype=object)

# %%
data['EmpDepartment'].unique()
# Out:
# array(['Sales', 'Human Resources', 'Development', 'Data Science',
#        'Research & Development', 'Finance'], dtype=object)

# %%
data['EmpJobRole'].unique()
# Out:
# array(['Sales Executive', 'Manager', 'Developer', 'Sales Representative',
#        'Human Resources', 'Senior Developer', 'Data Scientist',
#        'Senior Manager R&D', 'Laboratory Technician',
#        'Manufacturing Director', 'Research Scientist',
#        'Healthcare Representative', 'Research Director', 'Manager R&D',
#        'Finance Manager', 'Technical Architect', 'Business Analyst',
#        'Technical Lead', 'Delivery Manager'], dtype=object)

# %%
data['BusinessTravelFrequency'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
data['DistanceFromHome'].unique()
# Out:
# array([10, 14,  5, 16,  8,  1, 24,  3, 27, 19,  9,  2,  7,  6, 26, 11, 23,
#        13, 29, 12,  4, 25, 21, 18, 20, 17, 22, 28, 15], dtype=int64)

# %%
data['EmpEducationLevel'].unique()
# Out:
# array([3, 4, 2, 5, 1], dtype=int64)

# %%
data['EmpEnvironmentSatisfaction'].unique()
# Out:
# array([4, 2, 1, 3], dtype=int64)

# %%
data['EmpHourlyRate'].unique()
# Out:
# array([ 55,  42,  48,  73,  84,  32,  54,  67,  63,  81,  49,  99,  57,
#         96,  44,  86,  83,  61,  80,  31,  46,  79,  77,  60,  76,  41,
#         71,  66,  38,  72,  95,  82,  75,  93,  64,  36,  69,  33,  35,
#         40,  43,  51,  52,  98,  45,  37,  94,  59,  88,  50,  65,  53,
#         56,  78,  74,  91,  62,  87,  68,  34,  70, 100,  92,  39,  97,
#         47,  90,  85,  30,  58,  89], dtype=int64)

# %%
data['EmpJobInvolvement'].unique()
# Out:
# array([3, 2, 1, 4], dtype=int64)

# %%
data['EmpJobLevel'].unique()
# Out:
# array([2, 3, 5, 1, 4], dtype=int64)

# %%
data['EmpJobSatisfaction'].unique()
# Out:
# array([4, 1, 2, 3], dtype=int64)

# %%
data['EmpJobSatisfaction'].value_counts()
# Out:
# 4    378
# 3    354
# 2    237
# 1    231
# Name: EmpJobSatisfaction, dtype: int64

# %%
data['NumCompaniesWorked'].unique()
# Out:
# array([1, 2, 5, 3, 8, 7, 9, 4, 6, 0], dtype=int64)

# %%
data['OverTime'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['EmpLastSalaryHikePercent'].unique()
# Out:
# array([12, 21, 15, 14, 13, 23, 11, 20, 19, 17, 18, 22, 16, 24, 25],
#       dtype=int64)

# %%
data['EmpRelationshipSatisfaction'].unique()
# Out:
# array([4, 3, 2, 1], dtype=int64)

# %%
data['EmpRelationshipSatisfaction'].value_counts()
# Out:
# 3    379
# 4    355
# 2    247
# 1    219
# Name: EmpRelationshipSatisfaction, dtype: int64

# %%
data['TotalWorkExperienceInYears'].unique()
# Out:
# array([10, 20, 23,  9,  4, 28,  1,  7, 12, 30,  5,  2, 19, 16, 34,  6,  8,
#        11, 17,  3, 14, 26, 13, 22,  0, 29, 18, 35, 33, 31, 24, 15, 32, 21,
#        27, 25, 36, 37, 38, 40], dtype=int64)

# %%
data['TrainingTimesLastYear'].unique()
# Out:
# array([2, 1, 4, 5, 6, 3, 0], dtype=int64)

# %%
data['EmpWorkLifeBalance'].unique()
# Out:
# array([2, 3, 4, 1], dtype=int64)

# %%
data['ExperienceYearsAtThisCompany'].unique()
# Out:
# array([10,  7, 18, 21,  2,  9,  8,  1,  5, 22,  4,  0, 34,  6, 15,  3, 13,
#        26, 20, 12, 31, 16, 11, 14, 17, 19, 32, 24, 33, 29, 25, 36, 30, 23,
#        27, 37, 40], dtype=int64)

# %%
data['ExperienceYearsInCurrentRole'].unique()
# Out:
# array([ 7, 13,  6,  2,  0,  1,  3,  8,  9,  5,  4, 14, 12, 10, 16, 11, 15,
#        17, 18], dtype=int64)

# %%
data['YearsSinceLastPromotion'].unique()
# Out:
# array([ 0,  1, 12,  2,  3, 11,  7,  4,  5, 14,  8, 15,  6, 10, 13,  9],
#       dtype=int64)

# %%
data['YearsWithCurrManager'].unique()
# Out:
# array([ 8,  7, 12,  6,  2,  5,  0,  4, 13,  3,  1, 16,  9, 17, 11, 10, 14,
#        15], dtype=int64)

# %%
data['Attrition'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['PerformanceRating'].unique()
# Out:
# array([3, 4, 2], dtype=int64)

# %% [markdown]
# ### Visualizing the data

# %%
sns.distplot(data['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(5,5))
sns.countplot(data['Gender'], palette = "Blues")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### More Male workers with respect to Female workers

# %%
plt.figure(figsize=(10,5))
sns.countplot(data['EducationBackground'], palette = "Blues")
# Out:
# <AxesSubplot:xlabel='EducationBackground', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(data['MaritalStatus'],palette = "Blues")
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
mylabels = ["Single", "Married", "Divorced"]
plt.pie(data['MaritalStatus'].value_counts(),labels = mylabels, radius= 2.0, autopct = '%0.1f%%')
plt.suptitle('Employee Marital Status', x = 0.55, y = 1.15, color = 'red')
plt.show()

# %% [markdown]
# #### This chart clearly shows the most of employee facing issue in personal life which also affect their job life

# %%
mylabels = [1,2,3,4]
plt.pie(data['EmpRelationshipSatisfaction'].value_counts(),labels = mylabels, radius= 2.0, autopct = '%0.1f%%')
plt.suptitle('Employee Relationship Satisfaction', x = 0.55, y = 1.15, color = 'red')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(data['EmpJobRole'],hue = data['EmpJobInvolvement'], palette = "Blues")
# Out:
# <AxesSubplot:xlabel='EmpJobRole', ylabel='count'>

# %%
mylabels = ['Travel_Rarely', 'Travel_Frequently', 'Non-Travel']
plt.pie(data['BusinessTravelFrequency'].value_counts(),labels = mylabels, radius= 2.0, autopct = '%0.1f%%')
plt.suptitle('Percentage of Employee Travelling', x = 0.55, y = 1.15, color = 'red')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['ExperienceYearsInCurrentRole'],hue = data['EmpJobRole'], palette = "Blues")
# Out:
# <AxesSubplot:xlabel='ExperienceYearsInCurrentRole', ylabel='count'>

# %%
sns.countplot(data['EmpJobSatisfaction'], palette=["#004853", '#c4421a','#545454'] )
# Out:
# <AxesSubplot:xlabel='EmpJobSatisfaction', ylabel='count'>

# %%
plt.pie(data['EmpJobSatisfaction'].value_counts(), labels = [1,2,3,4],radius= 2.0, autopct = '%0.1f%%')
plt.suptitle('Percentage of Employee satisfied with their Job', x = 0.55, y = 1.15, color = 'red')
plt.show()

# %%
sns.countplot(data['EmpEnvironmentSatisfaction'], palette = "Blues")
# Out:
# <AxesSubplot:xlabel='EmpEnvironmentSatisfaction', ylabel='count'>

# %%
plt.pie(data['EmpEnvironmentSatisfaction'].value_counts(),labels = [1,2,3,4], radius= 2.0, autopct = '%0.1f%%')
plt.suptitle('Percentage of Employee satisfied with their Job Environment', x = 0.55, y = 1.15, color = 'red')
plt.show()

# %% [markdown]
# #### Majority of employee are not satisfied with enviornment at their job

# %%
plt.figure(figsize=(15,6))
sns.countplot(data['TotalWorkExperienceInYears'],hue = data['EmpDepartment'], palette = "Blues")
# Out:
# <AxesSubplot:xlabel='TotalWorkExperienceInYears', ylabel='count'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(data['EmpWorkLifeBalance'], palette = "Blues")
# Out:
# <AxesSubplot:xlabel='EmpWorkLifeBalance', ylabel='count'>

# %%
plt.pie(data['EmpWorkLifeBalance'].value_counts(),labels = [1,2,3,4], radius= 2.0, autopct = '%0.1f%%')
plt.suptitle('Employee Work Life Balance', x = 0.55, y = 1.15, color = 'red')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['EmpJobLevel'],hue = data['EmpJobRole'], palette = "Blues")
# Out:
# <AxesSubplot:xlabel='EmpJobLevel', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['EmpHourlyRate'],hue = data['OverTime'], palette = "Blues")
# Out:
# <AxesSubplot:xlabel='EmpHourlyRate', ylabel='count'>

# %%
plt.pie(data['EmpLastSalaryHikePercent'].value_counts(), radius= 2.0, autopct = '%0.1f%%')
plt.suptitle('Employees Salary Hike Percentage', x = 0.55, y = 1.15, color = 'red')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['EmpLastSalaryHikePercent'],hue = data['EmpDepartment'], palette = "Blues")
# Out:
# <AxesSubplot:xlabel='EmpLastSalaryHikePercent', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['TotalWorkExperienceInYears'],hue = data['EmpLastSalaryHikePercent'], palette = "Blues")
# Out:
# <AxesSubplot:xlabel='TotalWorkExperienceInYears', ylabel='count'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(data['ExperienceYearsInCurrentRole'], palette = "Blues")
# Out:
# <AxesSubplot:xlabel='ExperienceYearsInCurrentRole', ylabel='count'>

# %%
plt.pie(data['ExperienceYearsInCurrentRole'].value_counts(), radius= 2.0, autopct = '%0.1f%%')
plt.suptitle('Employees Experience in Current role', x = 0.55, y = 1.15, color = 'red')
plt.show()

# %% [markdown]
# ##### This chart clearly shows that most of the employee have less experience

# %%
sns.countplot(data['TrainingTimesLastYear'],palette = "Blues" )
# Out:
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='count'>

# %%
sns.boxplot(x = data['NumCompaniesWorked'], y = data['ExperienceYearsAtThisCompany'], palette = "Blues" )
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='ExperienceYearsAtThisCompany'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(data['YearsWithCurrManager'], palette = "Blues")
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='count'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(data['Attrition'], palette = "Blues")
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(data['PerformanceRating'], palette = "Blues")
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='count'>

# %%
plt.pie(data['PerformanceRating'].value_counts(),labels = [2,3,4], radius= 2.0, autopct = '%0.1f%%')
plt.suptitle('Percentage of Employees Performance rating', x = 0.55, y = 1.15, color = 'red')
plt.show()

# %% [markdown]
# ##### The above insights shows many conclusion due to which affect employee performance
